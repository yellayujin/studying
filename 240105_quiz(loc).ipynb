# %% [markdown]
# <a href="https://colab.research.google.com/github/yellayujin/mulcamp34/blob/main/240105_quiz(loc).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## (1) 라이브러리 불러오기
# - numpy, pandas, seaborn 라이브러리를 불러온다.

# %%
sns.get_dataset_names    # 여기 있는 샘플데이터셋으로 연습 가능
# Out:
# <function seaborn.utils.get_dataset_names()>

# %%
import numpy as np
import pandas as pd
import seaborn as sns   # 불러온 뒤 버전 체크 습관화!!
print(f'Numpy Version: {np.__version__}')
# Out:
# Numpy Version: 1.23.5

# %% [markdown]
# ## (2) 데이터 불러오기
# - tips 데이터를 불러와서 tips라고 저장한다.

# %%
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ## (3) 특정 행 추출
# - loc을 사용하여 tips 데이터셋의 처음 3행의 데이터를 추출하세요.

# %%
tips.loc[tips.index<=2, :]
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3

# %% [markdown]
# ## (4) 특정 열 추출
# - loc을 사용하여 모든 레코드에 대한 'total_bill'과 'tip' 열을 추출하세요.

# %%
tips.loc[:,['total_bill', 'tip']]

# loc: label기반
# iloc: index기반

'''
loc[0:2, : ]  # 0, 1, 2행 추출
iloc[0:2, : ] # 0, 1행 추출
'''
# Out:
#      total_bill   tip
# 0         16.99  1.01
# 1         10.34  1.66
# 2         21.01  3.50
# 3         23.68  3.31
# 4         24.59  3.61
# ..          ...   ...
# 239       29.03  5.92
# 240       27.18  2.00
# 241       22.67  2.00
# 242       17.82  1.75
# 243       18.78  3.00
#
# [244 rows x 2 columns]

# %% [markdown]
# ## (5) 특정 행과 열의 조합
# - loc을 사용하여 처음 5행에 대해 'total_bill', 'tip', 'day' 열을 추출하세요.

# %%
tips.head().loc[:, ['total_bill', 'tip', 'day']]
# Out:
#    total_bill   tip  day
# 0       16.99  1.01  Sun
# 1       10.34  1.66  Sun
# 2       21.01  3.50  Sun
# 3       23.68  3.31  Sun
# 4       24.59  3.61  Sun

# %% [markdown]
# ## (6) 조건에 따른 행 추출
# - 'day'가 'Sunday'인 모든 행을 추출하고 'total_bill'과 'tip' 열만 표시하세요.

# %%
tips.loc[tips['day']=='Sun', ['total_bill', 'tip']]
# Out:
#      total_bill   tip
# 0         16.99  1.01
# 1         10.34  1.66
# 2         21.01  3.50
# 3         23.68  3.31
# 4         24.59  3.61
# ..          ...   ...
# 186       20.90  3.50
# 187       30.46  2.00
# 188       18.15  3.50
# 189       23.10  4.00
# 190       15.69  1.50
#
# [76 rows x 2 columns]

# %% [markdown]
# ## (7) 다중 조건에 따른 행 추출
# - loc을 사용하여 'time'이 'Dinner'이고 'tip'이 5달러 이상인 모든 행을 선택하고 'total_bill', 'sex', 'smoker' 열만 표시하세요.

# %%
tips.loc[(tips['time']=='Dinner')&(tips['tip']>=5) , ['total_bill','sex','smoker']]
# Out:
#      total_bill     sex smoker
# 11        35.26  Female     No
# 23        39.42    Male     No
# 39        31.27    Male     No
# 44        30.40    Male     No
# 46        22.23    Male     No
# 47        32.40    Male     No
# 52        34.81  Female     No
# 59        48.27    Male     No
# 73        25.28  Female    Yes
# 116       29.93    Male     No
# 155       29.85  Female     No
# 156       48.17    Male     No
# 170       50.81    Male    Yes
# 172        7.25    Male    Yes
# 181       23.33    Male    Yes
# 183       23.17    Male    Yes
# 185       20.69    Male     No
# 211       25.89    Male    Yes
# 212       48.33    Male     No
# 214       28.17  Female    Yes
# 239       29.03    Male     No
